# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv("yellow_tripdata_2021-01.csv", nrows=100, index_col=0)
display(df)
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1          1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2          1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3          1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4          2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ..       ...                  ...                   ...              ...
# 95         2  2021-01-01 00:12:41   2021-01-01 00:26:47              1.0
# 96         2  2021-01-01 00:23:29   2021-01-01 00:35:03              2.0
# 97         2  2021-01-01 00:46:17   2021-01-01 00:54:25              2.0
# 98         2  2021-01-01 00:28:16   2021-01-01 00:51:44              1.0
# 99         2  2021-01-01 00:42:35   2021-01-01 00:54:41              3.0
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
print(pd.io.sql.get_schema(df, name = "yellow_taxi_data"))
#Creating table but need to transform date into dateformat
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "airport_fee" REAL
# )

# %%
df["tpep_pickup_datetime"] = pd.to_datetime(df["tpep_pickup_datetime"])
df["tpep_dropoff_datetime"] = pd.to_datetime(df["tpep_dropoff_datetime"])
print(pd.io.sql.get_schema(df, name = "yellow_taxi_data"))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "airport_fee" REAL
# )

# %%
for i, row in df.iterrows():
    print("data :", i, row , "\n")
# Out:
# data : 0 VendorID                                   1
# tpep_pickup_datetime     2021-01-01 00:30:10
# tpep_dropoff_datetime    2021-01-01 00:36:12
# passenger_count                          1.0
# trip_distance                            2.1
# RatecodeID                               1.0
# store_and_fwd_flag                         N
# PULocationID                             142
# DOLocationID                              43
# payment_type                               2
# fare_amount                              8.0
# extra                                    3.0
# mta_tax                                  0.5
# tip_amount                               0.0
# tolls_amount                             0.0
# improvement_surcharge                    0.3
# total_amount                            11.8
# congestion_surcharge                     2.5
# airport_fee                              NaN
# Name: 0, dtype: object
#
# data : 1 VendorID                                   1
# ...

# %%
engine = create_engine("postgresql://root:root@localhost:5432/ny_taxi")
#postgresql. user:pswd localhost:port/dbname

# %%
print(pd.io.sql.get_schema(df, name = "yellow_taxi_data",con = engine ))
#Saved as a postgre schema
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
### since the file is too big we are going to use an iterator
df_iter = pd.read_csv("yellow_tripdata_2021-01.csv",iterator=True, chunksize=100000,index_col=0 )

# %%
df_iter

# %%
df = next(df_iter)
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1             1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2             1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3             1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4             2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ...         ...                  ...                   ...              ...
# 99995         1  2021-01-04 14:04:31   2021-01-04 14:08:52              3.0
# 99996         1  2021-01-04 14:18:46   2021-01-04 14:35:45              2.0
# 99997         1  2021-01-04 14:42:41   2021-01-04 14:59:22              2.0
# 99998         2  2021-01-04 14:39:02   2021-01-04 15:09:37              2.0
# 99999         2  2021-01-04 14:49:36   2021-01-04 14:54:44              5.0
#
# ...

# %%
df["tpep_pickup_datetime"] = pd.to_datetime(df["tpep_pickup_datetime"])
df["tpep_dropoff_datetime"] = pd.to_datetime(df["tpep_dropoff_datetime"])

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df_iter.get_chunk(10)
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 100000         2  2021-01-04 14:42:51   2021-01-04 14:51:18              1.0
# 100001         2  2021-01-04 14:04:39   2021-01-04 14:18:41              1.0
# 100002         1  2021-01-04 14:12:49   2021-01-04 14:31:21              0.0
# 100003         1  2021-01-04 14:43:55   2021-01-04 14:48:45              1.0
# 100004         1  2021-01-04 14:59:16   2021-01-04 15:07:08              1.0
# 100005         2  2021-01-04 14:19:25   2021-01-04 14:27:25              1.0
# 100006         1  2021-01-04 14:05:13   2021-01-04 14:09:53              1.0
# 100007         1  2021-01-04 14:13:43   2021-01-04 14:25:17              1.0
# 100008         1  2021-01-04 14:39:19   2021-01-04 14:44:26              1.0
# 100009         1  2021-01-04 14:49:23   2021-01-04 15:08:45              1.0
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# ...

# %%
df_iter.get_chunk(8)
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 100121         2  2021-01-04 14:38:02   2021-01-04 14:49:47              1.0
# 100122         1  2021-01-04 14:25:32   2021-01-04 14:34:28              2.0
# 100123         1  2021-01-04 14:44:42   2021-01-04 14:58:11              1.0
# 100124         2  2021-01-04 14:28:06   2021-01-04 14:40:12              1.0
# 100125         2  2021-01-04 14:26:55   2021-01-04 14:38:25              1.0
# 100126         1  2021-01-04 14:54:46   2021-01-04 15:43:25              0.0
# 100127         1  2021-01-04 14:25:54   2021-01-04 15:04:55              1.0
# 100128         1  2021-01-04 14:13:29   2021-01-04 14:17:32              1.0
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 100121           2.04         1.0                  N            79
# 100122           1.80         1.0                  N           142
# 100123           2.60         1.0                  Y           237
# ...

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, airport_fee]
# Index: []

# %%
df.head(0).to_sql(name = "yellow_taxi_data", con=engine, if_exists="replace")
#Now we should have in our database a schema called yellow_taxi_data
#replace si existe deja

# %%
# %time df.to_sql(name = "yellow_taxi_data", con=engine, if_exists="append")
#mtn on insère des données
# Out:
# CPU times: user 6.56 s, sys: 482 ms, total: 7.04 s
# Wall time: 24.4 s

# %%
from time import time

# %%
while True:
    t_start = time()
    df=next(df_iter)
    df["tpep_pickup_datetime"] = pd.to_datetime(df["tpep_pickup_datetime"])
    df["tpep_dropoff_datetime"] = pd.to_datetime(df["tpep_dropoff_datetime"])
    df.to_sql(name = "yellow_taxi_data", con=engine, if_exists="append")
    t_end=time()
    print("Inserted another chunk, it took : %3.f seconds" %(t_end-t_start))
# Out:
# Inserted another chunk, it took :  19 seconds
# Inserted another chunk, it took :  23 seconds
# Inserted another chunk, it took :  27 seconds
# Inserted another chunk, it took :  30 seconds
# Inserted another chunk, it took :  24 seconds
# Inserted another chunk, it took :  28 seconds
# Inserted another chunk, it took :  26 seconds
# Inserted another chunk, it took :  27 seconds
# Inserted another chunk, it took :  30 seconds
# Inserted another chunk, it took :  30 seconds
# Inserted another chunk, it took :  26 seconds
# /Users/adrien/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3364: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Inserted another chunk, it took :  29 seconds
# Inserted another chunk, it took :  16 seconds
# ---------------------------------------------------------------------------
# ...
